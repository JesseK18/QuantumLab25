# %% [markdown]
# # Grover\'s Algorithm
#
#
# Grover\'s algorithm is an oracle-based quantum algorithm, proposed by Lov Grover.
# In the original description, the author approaches the following problem: suppose that we are searching for a specific phone number in a randomly-ordered catalogue containing $N$ entries.
# To find such a number with a probability of $\frac{1}{2},$ a classical algorithm will need to check the list on average $\frac{N}{2}$ times.
#
# In other words, the problem is defined by searching for an item on a list with $N$ items given an Oracle access function $f(x).$
# This function has the defining property that $f(x) = 1$ if $x$ is the item we are looking for, and $f(x) = 0$ otherwise.
# The solution to this black-box search problem is proposed as a quantum algorithm that performs $O(\sqrt{N})$ oracular queries to the list with a high probability of finding the answer, whereas any classical algorithm would require $O(N)$ queries.

# %% [markdown]
# -----------------------------------------------------
# ##### The problem
# *Input*: A black box $U_f$ for computing an unknown function $f: \{0,1\}^n \to \{0, 1\} $
#
# *Output*: An index $x$ such that $f(x) = 1$.
#
# ----------------------------------------------------

# %% [markdown]
# The algorithm can be broken down into the following steps:
#
# 1. Prepare the initial state (Apply Hadamard gates to all wires)
# 2. Repeat the Grover operator approximately $\frac{\pi}{4}\sqrt{N}$ times:
#     - Apply the oracle
#     - Apply the Grover diffusion operator
# 3. Apply Hadamard gates to all wires
# 4. Measure
#
#
# We can visualize the algorithm as follows:
#
# <img src="Image/grover circ.png"  width = 600/>
#
# where the grover operator G is defined as:
#
# <img src="Image/G.png" alt="Grover's operator" width = 600/>

# %% [markdown]
# ## Defining the Oracle
#
# Suppose we have a function $f$ representing our search problem (i.e., $f(x) = 1$ if $x$ is the solution of the search problem, $f(x) = 0$ otherwise).
#
# The oracle is a unitary operator $O$ acting in the following way:
# $$ |x\rangle|q\rangle \xrightarrow{O} |x\rangle|q \oplus f(x)\rangle $$
#
#
#
# ### Example of an Oracle
#
# Let us consider a simple example of an oracle that marks a particular state.
#
#
# These are the oracles of the form of $f_i(x) = \begin{cases} 1 & x = i \\ 0, & x \neq i \end{cases}$ for $i = 0, 1, 2, 3$.
#
# For instance, for two qubits we have:
#
# <img src="Image/oracle.png" alt="Oracle" width = 600/>

# %%
! pip install qiskit
! pip install pylatexenc
! pip install qiskit-aer
! pip install matplotlib
! pip install numpy
! pip install qiskit-terra
! pip install qiskit-ibm-runtime
! pip install qiskit-optimization
! pip install qiskit-machine-learning
# Out:
# Requirement already satisfied: qiskit in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit) (1.13.0)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit) (5.8.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit) (4.11.0)
# Requirement already satisfied: pylatexenc in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (2.10)
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-aer) (2.4.1)
# Requirement already satisfied: numpy>=1.16.3 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-aer) (1.13.0)
# Requirement already satisfied: psutil>=5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-aer) (5.9.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.8.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.11.0)
# Downloading qiskit_aer-0.17.2-cp311-cp311-macosx_10_9_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 5.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.17.2
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (1.26.4)
# Collecting qiskit-terra
#   Downloading qiskit_terra-0.46.3-cp38-abi3-macosx_10_9_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: rustworkx>=0.13.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (1.26.4)
# Requirement already satisfied: ply>=3.10 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (3.11)
# Requirement already satisfied: psutil>=5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (5.9.0)
# Requirement already satisfied: scipy>=1.5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (1.13.0)
# Requirement already satisfied: sympy>=1.3 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (1.12.1)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (0.4.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-terra) (5.8.0)
# Collecting symengine>=0.11 (from qiskit-terra)
#   Downloading symengine-0.14.1-cp311-cp311-macosx_10_13_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-terra) (1.16.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from sympy>=1.3->qiskit-terra) (1.3.0)
# Downloading qiskit_terra-0.46.3-cp38-abi3-macosx_10_9_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 8.2 MB/s eta 0:00:0000:0100:01m
# Downloading symengine-0.14.1-cp311-cp311-macosx_10_13_x86_64.whl (26.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 8.9 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: symengine, qiskit-terra
# Successfully installed qiskit-terra-0.46.3 symengine-0.14.1
# Collecting qiskit-ibm-runtime
#   Downloading qiskit_ibm_runtime-0.47.0-py3-none-any.whl.metadata (23 kB)
# Collecting requests>=2.32.4 (from qiskit-ibm-runtime)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-ibm-runtime) (1.26.4)
# Collecting urllib3>=2.4.0 (from qiskit-ibm-runtime)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: python-dateutil>=2.9.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.61.1 (from qiskit-ibm-runtime)
#   Downloading ibm_platform_services-0.75.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting ibm-quantum-schemas<1,>=0.7.20260419 (from qiskit-ibm-runtime)
#   Downloading ibm_quantum_schemas-0.7.20260419-py3-none-any.whl.metadata (3.0 kB)
# Collecting pydantic>=2.11.0 (from qiskit-ibm-runtime)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: qiskit>=2.2.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.4.1)
# Collecting pybase64>=1.4.0 (from qiskit-ibm-runtime)
#   Downloading pybase64-1.4.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.7 kB)
# Collecting samplomatic>=0.13.0 (from qiskit-ibm-runtime)
#   Downloading samplomatic-0.19.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.4 (from ibm-platform-services>=0.61.1->qiskit-ibm-runtime)
#   Downloading ibm_cloud_sdk_core-3.24.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.11.0->qiskit-ibm-runtime)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic>=2.11.0->qiskit-ibm-runtime)
#   Downloading pydantic_core-2.46.4-cp311-cp311-macosx_10_12_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.14.1 (from pydantic>=2.11.0->qiskit-ibm-runtime)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.11.0->qiskit-ibm-runtime)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from python-dateutil>=2.9.0->qiskit-ibm-runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (1.13.0)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (5.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.7)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (2024.8.30)
# Collecting cryptography>=1.3 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Downloading cryptography-48.0.0-cp311-abi3-macosx_10_9_universal2.whl.metadata (4.3 kB)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Downloading pyspnego-0.12.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting orjson>=3.9.0 (from samplomatic>=0.13.0->qiskit-ibm-runtime)
#   Downloading orjson-3.11.9-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.4 MB/s eta 0:00:00
# Collecting cffi>=2.0.0 (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Downloading cffi-2.0.0-cp311-cp311-macosx_10_13_x86_64.whl.metadata (2.6 kB)
# Collecting PyJWT<3.0.0,>=2.11.0 (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.61.1->qiskit-ibm-runtime)
#   Downloading pyjwt-2.13.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.21)
# Downloading qiskit_ibm_runtime-0.47.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.0 MB/s eta 0:00:0000:0100:01
# Downloading ibm_platform_services-0.75.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.8/386.8 kB 6.3 MB/s eta 0:00:00:00:01
# Downloading ibm_quantum_schemas-0.7.20260419-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 3.5 MB/s eta 0:00:00
# Downloading pybase64-1.4.3-cp311-cp311-macosx_10_9_x86_64.whl (38 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 11.8 MB/s eta 0:00:0000:01
# Downloading pydantic_core-2.46.4-cp311-cp311-macosx_10_12_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.3 MB/s eta 0:00:0000:0100:01
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.4 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading samplomatic-0.19.0-py3-none-any.whl (218 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 7.3 MB/s eta 0:00:00
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 4.6 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cryptography-48.0.0-cp311-abi3-macosx_10_9_universal2.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 29.2 MB/s eta 0:00:0000:0100:01
# Downloading ibm_cloud_sdk_core-3.24.4-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 2.4 MB/s eta 0:00:00
# Downloading orjson-3.11.9-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.5/228.5 kB 7.6 MB/s eta 0:00:00
# Downloading pyspnego-0.12.1-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 3.9 MB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading cffi-2.0.0-cp311-cp311-macosx_10_13_x86_64.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 6.3 MB/s eta 0:00:00
# Downloading pyjwt-2.13.0-py3-none-any.whl (31 kB)
# Installing collected packages: urllib3, typing-extensions, PyJWT, pybase64, orjson, cffi, annotated-types, typing-inspection, requests, pydantic-core, cryptography, samplomatic, pyspnego, pydantic, ibm_cloud_sdk_core, requests-ntlm, ibm-quantum-schemas, ibm-platform-services, qiskit-ibm-runtime
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.16.0
#     Uninstalling cffi-1.16.0:
#       Successfully uninstalled cffi-1.16.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.2
#     Uninstalling requests-2.32.2:
#       Successfully uninstalled requests-2.32.2
# Successfully installed PyJWT-2.13.0 annotated-types-0.7.0 cffi-2.0.0 cryptography-48.0.0 ibm-platform-services-0.75.0 ibm-quantum-schemas-0.7.20260419 ibm_cloud_sdk_core-3.24.4 orjson-3.11.9 pybase64-1.4.3 pydantic-2.13.4 pydantic-core-2.46.4 pyspnego-0.12.1 qiskit-ibm-runtime-0.47.0 requests-2.34.2 requests-ntlm-1.3.0 samplomatic-0.19.0 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.7.0
# Collecting qiskit-optimization
#   Downloading qiskit_optimization-0.7.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: qiskit<3,>=1.1 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-optimization) (2.4.1)
# Requirement already satisfied: scipy>=1.9.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-optimization) (1.13.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-optimization) (1.26.4)
# Collecting docplex!=2.24.231,>=2.21.207 (from qiskit-optimization)
#   Downloading docplex-2.32.264.tar.gz (663 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.0/664.0 kB 5.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=40.1.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-optimization) (69.5.1)
# Requirement already satisfied: networkx>=2.6.3 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-optimization) (3.3)
# Requirement already satisfied: six in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from docplex!=2.24.231,>=2.21.207->qiskit-optimization) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit<3,>=1.1->qiskit-optimization) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit<3,>=1.1->qiskit-optimization) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit<3,>=1.1->qiskit-optimization) (5.8.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit<3,>=1.1->qiskit-optimization) (4.15.0)
# Downloading qiskit_optimization-0.7.0-py3-none-any.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.1/237.1 kB 6.9 MB/s eta 0:00:00
# Building wheels for collected packages: docplex
#   Building wheel for docplex (pyproject.toml) ... done
#   Created wheel for docplex: filename=docplex-2.32.264-py3-none-any.whl size=703859 sha256=b57b0ac1c253f44606031469724a799ef96d9e53b87e0859ca8d42033d786e32
#   Stored in directory: /Users/jessekroll/Library/Caches/pip/wheels/a9/ce/4e/ce5ae65cfdd897cca0544e8dda26f32d3cc20d5e25dcc461a3
# Successfully built docplex
# Installing collected packages: docplex, qiskit-optimization
# Successfully installed docplex-2.32.264 qiskit-optimization-0.7.0
# Collecting qiskit-machine-learning
#   Downloading qiskit_machine_learning-0.9.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: qiskit>=2.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-machine-learning) (2.4.1)
# Collecting numpy>=2.0 (from qiskit-machine-learning)
#   Downloading numpy-2.4.6-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: scipy>=1.4 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-machine-learning) (1.13.0)
# Requirement already satisfied: scikit-learn>=1.2 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-machine-learning) (1.2.2)
# Requirement already satisfied: setuptools>=40.1 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-machine-learning) (69.5.1)
# Requirement already satisfied: dill>=0.3.4 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit-machine-learning) (0.4.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=2.0->qiskit-machine-learning) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=2.0->qiskit-machine-learning) (5.8.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from qiskit>=2.0->qiskit-machine-learning) (4.15.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/ML_assignment_4/lib/python3.11/site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (2.2.0)
#   Downloading numpy-2.2.6-cp311-cp311-macosx_10_9_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.6 MB/s eta 0:00:00
# Downloading qiskit_machine_learning-0.9.0-py3-none-any.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.1/263.1 kB 7.4 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp311-cp311-macosx_10_9_x86_64.whl (21.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.2/21.2 MB 16.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy, qiskit-machine-learning
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.2.6 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.2.6 which is incompatible.
# Successfully installed numpy-2.2.6 qiskit-machine-learning-0.9.0

# %%
# NumPy: used elsewhere in the lab for amplitudes / simulation (not required inside this function)
import numpy as np
# XGate: Pauli-X; we build an N-controlled X from it for the phase-kick trick
from qiskit.circuit.library import XGate
# QuantumCircuit: container for gates on N search qubits + 1 ancilla
from qiskit import QuantumCircuit

def create_f_oracle(marked, N):
    """
    Grover phase oracle for the computational basis state |marked⟩.

    marked: integer index of the tagged state (0 .. 2^N - 1)
    N: number of search qubits (not counting the ancilla)
    """
    # N+1 qubits: indices 0..N-1 are the register; qubit N is the ancilla (|−⟩ during Grover)
    qc = QuantumCircuit(N+1, name=f"Oracle {marked}")

    # Write 'marked' as an N-bit string, e.g. marked=2, N=2 → '10'
    marked_base2 = format(marked, f'0{N}b')
    # Qiskit: qubit 0 is LSB. format() prints MSB first, so reverse to match qubit indices
    marked_base2 = marked_base2[::-1]  # e.g. '10' → '01' (|marked⟩ = |q1 q0⟩ in little-endian)

    # Layer 1: map |marked⟩ → |11…1⟩ by flipping qubits where marked has a 0
    for i in range(N):
        if marked_base2[i] == '0':
            qc.x(i)

    # Layer 2: (N+1)-controlled X on ancilla qubit N — flips ancilla iff register is |11…1⟩
    # With ancilla in |−⟩, this implements a phase (−1) on |marked⟩ only (standard Grover oracle)
    qc.append(XGate().control(N), range(N+1))  # same idea as qc.mcx(range(N), N)

    # Layer 3: undo the X gates so only the marked basis state picked up the phase
    for i in range(N):
        if marked_base2[i] == '0':
            qc.x(i)

    return qc

# Example: 2 search qubits, tag state |2⟩ = |10⟩ (decimal 2); draw the circuit
create_f_oracle(2, 2).draw('mpl')

# %% [markdown]
# We can test the oracle by applying it to a uniform superposition

# %%
from qiskit import transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

N = 3

num = 3

qc = QuantumCircuit(N+1)

qc.h(range(N)) # create the uniform superposition
qc.append(create_f_oracle(num, N), range(N+1)) # apply the oracle
qc.measure_all()

simulator = AerSimulator()
    
circ = transpile(qc, simulator)
result = simulator.run(circ).result()
counts = result.get_counts(circ)
plot_histogram(counts)

# %% [markdown]
# ## Grover Diffusion Operator
#
# Now we need to amplify the amplitude of the good state.
#
# When $|q\rangle = |-\rangle$, the action of the oracle is:
# $$ |x\rangle|-\rangle \xrightarrow{O} (-1)^{f(x)}|x\rangle|-\rangle $$
# Thus, the action of the oracle can be written as:
# $$ |x\rangle \xrightarrow{O} (-1)^{f(x)}|x\rangle $$
#
# To perform the amplification, we need to apply the Grover diffusion operator.
# The Grover diffusion operator is defined as:
# $$ G = 2|s\rangle\langle s| - I = H^{\otimes n} \left(2|0\rangle\langle 0| - I\right) H^{\otimes n} $$
#
# where $|s\rangle$ is the uniform superposition of all states.
#
# The diffusion operator can be implemented as follows:
#
# <img src="Image/grover_diffusion.png" alt="Diffusion operator" width="400"/>

# %%
from qiskit.circuit.library import ZGate


def create_diffusion_operator(N):
    qc = QuantumCircuit(N, name="Diff")
    qc.h(range(N))
    qc.x(range(N))
    qc.append(ZGate().control(N-1), range(N))
    qc.x(range(N))
    qc.h(range(N))
    return qc

qc = create_diffusion_operator(5)
qc.draw('mpl')

# %% [markdown]
# ## Putting all together
#
# Let us now put all the pieces together and implement Grover's algorithm.

# %%
import math


def create_grover_circuit(num_qbits, marked):
    assert marked in range(2**num_qbits)


    grover = QuantumCircuit(num_qbits+1, num_qbits)

    grover.x(num_qbits) # create the |0> state

    grover.h(range(num_qbits+1)) # create the uniform superposition

    grover.barrier()
    
    oracle = create_f_oracle(marked, num_qbits) # Create the oracle
    
    diffusion = create_diffusion_operator(num_qbits) # Create the diffusion operator
    
    R = int(np.round(np.sqrt(num_qbits) * np.pi / 4))
    for i in range(R):
        
        grover.append(oracle, range(num_qbits+1))
        grover.barrier()
        grover.append(diffusion, range(num_qbits))
        grover.barrier()
        
    #grover.h(range(num_qbits+1)) # Apply Hadamard gates to all wires
        
    
    # grover.save_statevector()
    grover.measure(range(num_qbits), range(num_qbits))
    
    return grover



# create_grover_circuit(2,0).decompose().draw('mpl')
create_grover_circuit(4,0).draw('mpl')

# %% [markdown]
# Let\'s use a bar plot to better visualize the initial state amplitudes:

# %%
qc = create_grover_circuit(5,2)
print(qc.draw())
# print(qc.decompose().draw())
circ = transpile(qc, simulator)
result = simulator.run(circ).result()
# print(result.get_statevector(circ).data)
counts = result.get_counts(circ)
plot_histogram(counts)
# Out:
#      ┌───┐      ░ ┌───────────┐ ░ ┌───────┐ ░ ┌───────────┐ ░ ┌───────┐ ░ ┌─┐»
# q_0: ┤ H ├──────░─┤0          ├─░─┤0      ├─░─┤0          ├─░─┤0      ├─░─┤M├»
#      ├───┤      ░ │           │ ░ │       │ ░ │           │ ░ │       │ ░ └╥┘»
# q_1: ┤ H ├──────░─┤1          ├─░─┤1      ├─░─┤1          ├─░─┤1      ├─░──╫─»
#      ├───┤      ░ │           │ ░ │       │ ░ │           │ ░ │       │ ░  ║ »
# q_2: ┤ H ├──────░─┤2          ├─░─┤2 Diff ├─░─┤2          ├─░─┤2 Diff ├─░──╫─»
#      ├───┤      ░ │  Oracle 2 │ ░ │       │ ░ │  Oracle 2 │ ░ │       │ ░  ║ »
# q_3: ┤ H ├──────░─┤3          ├─░─┤3      ├─░─┤3          ├─░─┤3      ├─░──╫─»
#      ├───┤      ░ │           │ ░ │       │ ░ │           │ ░ │       │ ░  ║ »
# q_4: ┤ H ├──────░─┤4          ├─░─┤4      ├─░─┤4          ├─░─┤4      ├─░──╫─»
#      ├───┤┌───┐ ░ │           │ ░ └───────┘ ░ │           │ ░ └───────┘ ░  ║ »
# q_5: ┤ X ├┤ H ├─░─┤5          ├─░───────────░─┤5          ├─░───────────░──╫─»
#      └───┘└───┘ ░ └───────────┘ ░           ░ └───────────┘ ░           ░  ║ »
# c: 5/══════════════════════════════════════════════════════════════════════╩═»
#                                                                            0 »
# «
# «q_0: ────────────
# «     ┌─┐
# «q_1: ┤M├─────────
# «     └╥┘┌─┐
# «q_2: ─╫─┤M├──────
# «      ║ └╥┘┌─┐
# «q_3: ─╫──╫─┤M├───
# «      ║  ║ └╥┘┌─┐
# «q_4: ─╫──╫──╫─┤M├
# «      ║  ║  ║ └╥┘
# «q_5: ─╫──╫──╫──╫─
# «      ║  ║  ║  ║
# «c: 5/═╩══╩══╩══╩═
# «      1  2  3  4

# %% [markdown]
# Useful links: [https://averyparkinson23.medium.com/solving-sudoku-using-quantum-computing-cbc8a397a504](https://averyparkinson23.medium.com/solving-sudoku-using-quantum-computing-cbc8a397a504)
